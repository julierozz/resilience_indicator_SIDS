# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_helper import get_list_of_index_names, broadcast_simple, concat_categories

# %matplotlib inline

# %% [markdown]
# This is just for SIDS at the moment. Can be updated for all countries when we have the data

# %%
#Names to WB names
any_to_wb = pd.read_csv("inputs/any_name_to_wb_name.csv",index_col="any",squeeze=True)

#GAR names with SIDS spec
gar_name_sids = pd.read_csv("inputs/gar_name_sids.csv")

#iso3 to wb country name table
iso3_to_wb=pd.read_csv("inputs/iso3_to_wb_name.csv").set_index("iso3").squeeze()

#iso2 to iso3 table
iso2_iso3 = pd.read_csv("inputs/names_to_iso.csv", usecols=["iso2","iso3"]).drop_duplicates().set_index("iso2").squeeze() #the tables has more lines than countries to account for several ways of writing country names

# %%
path = "sids data\\"

# %% [markdown]
# ## Roads -- km from OSM and hard coding road costs

# %%
roads = pd.read_csv(path+"km_roads_sids.csv")

# %%
roads[['Total Length (km)', 'Total Primary',\
       'Total Secondary', 'Total Tertiary', 'Residential', 'Track / service',\
       'Total Other']] = roads[['Total Length (km)', 'Total Primary',\
       'Total Secondary', 'Total Tertiary', 'Residential', 'Track / service',\
       'Total Other']].astype(float)

# %%
roads["country"] = roads.country.replace(any_to_wb)

# %%
#cost per km of road based on st Lucia data. 
primary_road_cost = 1200000
secondary_road_cost = 700000
tertiary_road_cost = 600000

# %%
#reduced road values because of depreciation.
lifetime_primary = 20
lifetime_secondary = 15
lifetime_tertiary = 10

# %%
roads = roads.fillna(0)
roads = roads.set_index("country")

# %%
roads["average_age_primary"] = 8
roads["average_age_secondary"] = 5
roads["average_age_tertiary"] = 5

# %%
roads.loc["Kiribati","average_age_primary"]=12

# %%
roads["transport"] = roads["Total Primary"]*primary_road_cost*(1-1/lifetime_primary*roads.average_age_primary)+\
                             roads["Total Secondary"]*secondary_road_cost*(1-1/lifetime_secondary*roads.average_age_secondary)+\
                             roads["Total Tertiary"]*tertiary_road_cost*(1-1/lifetime_tertiary*roads.average_age_tertiary)+\
                             roads["Residential"]*tertiary_road_cost*(1-1/lifetime_tertiary*roads.average_age_tertiary)+\
                             roads["Track / service"]*tertiary_road_cost*(1-1/lifetime_tertiary*roads.average_age_tertiary)+\
                             roads["Total Other"]*tertiary_road_cost*(1-1/lifetime_tertiary*roads.average_age_tertiary)

# %%
roads.sample(5)
# Out:
#                      ISO Projection   EPSG       Sheet  Total Length (km)  \
# country
# Antigua and Barbuda  ATG     UTM20N  32620  ATG_UTM20N        1368.449906
# Tonga                TON      UTM1S  32701   TON_UTM1S        1814.821691
# Belize               BLZ     UTM16N  32616  BLZ_UTM16N        7531.270880
# Timor-Leste          TLS     UTM51S  32751  TLS_UTM51S        4315.364731
# Dominican Republic   DOM     UTM19N  32619  DOM_UTM19N       30130.487590
#
#                      Total Primary  Total Secondary  Total Tertiary  \
# country
# Antigua and Barbuda     104.578230        70.561461       54.123172
# Tonga                    47.960584        56.148991      197.228790
# Belize                  544.474369       150.266118      576.363897
# Timor-Leste            1193.549790       370.965926      609.299211
# Dominican Republic     2826.929026      2548.319922     2824.837829
#
#                       Residential  Track / service  Total Other  \
# country
# Antigua and Barbuda    757.917842       379.964498     1.304702
# Tonga                  410.042833       819.051123   284.389371
# Belize                1730.025635      2708.992860  1821.148001
# Timor-Leste            542.721903       611.369563   987.458337
# Dominican Republic   15543.043840      4524.683917  1862.673058
#
#                      average_age_primary  average_age_secondary  \
# country
# Antigua and Barbuda                    8                      5
# Tonga                                  8                      5
# Belize                                 8                      5
# Timor-Leste                            8                      5
# Dominican Republic                     8                      5
#
#                      average_age_tertiary     transport
# country
# Antigua and Barbuda                     5  4.662181e+08
# Tonga                                   5  5.739481e+08
# Belize                                  5  2.513105e+09
# Timor-Leste                             5  1.857728e+09
# Dominican Republic                      5  1.065118e+10

# %% [markdown]
# ## Power (from Platts)

# %%
power = pd.read_csv(path+"power_plants_sids.csv")
power["country"] = power.COUNTRY.apply(lambda x:x.title()).replace(any_to_wb)

# %%
power["power"] = power.CAPEX

# %% [markdown]
# ## Buildings data from Rashmin and PCRAFI

# %%
buildings_pcrafi = pd.read_csv(path+"PCRAFI_stocks.csv")
#values in million USD

# %%
#we divide by 3 because for Fiji PCRAFI is 3 times higher than Rashmin's assessment, which is consistent with GAR
buildings_pcrafi["country"] = buildings_pcrafi.country.replace(any_to_wb)
buildings_pcrafi = 1/3*10**6*buildings_pcrafi.set_index("country")

# %%
#buildings_pcrafi.rename(columns={"building":"total_building_value"},inplace=True)

# %%
buildings_pcrafi
# Out:
#                            building  infrastructure
# country
# Cook Islands           4.322667e+08    3.920000e+07
# Fiji                   6.288400e+09    1.031300e+09
# Micronesia, Fed. Sts.  5.763333e+08    1.042667e+08
# Kiribati               3.353667e+08    5.473333e+07
# Marshall Islands       4.680333e+08    9.530000e+07
# Nauru                  5.793333e+07    2.466667e+07
# Niue                   1.368667e+08    1.400000e+07
# Papua New Guinea       1.316967e+10    2.213033e+09
# Palau                  4.461667e+08    5.330000e+07
# Solomon Islands        1.019567e+09    1.401000e+08
# Timor-Leste            5.960433e+09    7.202000e+08
# Tonga                  8.417333e+08    8.646667e+07
# Tuvalu                 7.643333e+07    1.323333e+07
# Vanuatu                9.528000e+08    1.400000e+08
# Samoa                  7.159667e+08    1.558000e+08

# %%
buildings_rashmin = pd.read_csv(path+"Gross_Capital_Summary.csv")
buildings_rashmin["country"] = buildings_rashmin.country.replace(iso3_to_wb).replace(any_to_wb)

# %%
buildings_rashmin["building"] = buildings_rashmin["Buildings (Residential + Non-Res)"]

# %%
buildings_rashmin.set_index("country").building
# Out:
# country
# Belize                4.620789e+09
# St. Lucia             3.197446e+09
# Jamaica               3.822092e+10
# Haiti                 2.656431e+10
# Grenada               2.131954e+09
# Dominican Republic    1.530000e+11
# Fiji                  6.504790e+09
# FJI est 2                      NaN
# Name: building, dtype: float64

# %%
#Fiji has 2 estimates. first one is rashmin, last one is PCRAFI
buildings = pd.concat([buildings_rashmin.set_index("country"),buildings_pcrafi]).reset_index().drop_duplicates("country",keep="first")

# %% [markdown]
# ### Residential vs non residential buildings

# %%
buildings = buildings.set_index("country")
## hard coding Fiji data from Rashmin's file Fiji_2015_exposure_estimation_110517.xlsx
fiji_total = 4093521135+2411268610
fiji_residential = 4093521135/fiji_total

# for the US, according to the BEA, residential is 19,199.1 billion and non residential 21,879.4 billion. so by default we put 50/50.
buildings["building_residential"] = buildings.building*0.5
buildings["building_non_residential"] = buildings.building*0.5
buildings.loc["Fiji","building_residential"] = buildings.loc["Fiji","building"]*fiji_residential
buildings.loc["Fiji","building_non_residential"] = buildings.loc["Fiji","building"]*(1-fiji_residential)

# %% [markdown]
# ## Water from WASH infrastructure needs

# %%
water = pd.read_csv(path+"water_infra_value_sids.csv")

# %%
water["country"] = water["country"].replace(any_to_wb)
water.set_index("country").sample()
# Out:
#                 water
# country
# Haiti    1.271568e+09

# %% [markdown]
# ## Merge all available infra

# %%
all_infra = pd.concat([roads.transport,power.set_index("country").power,\
                       buildings[["building_residential","building_non_residential"]],water.set_index("country")],axis=1)

# %%
all_infra = all_infra.unstack().reset_index().rename(columns={"level_0":"sector","level_1":"country",0:"infra_k"}).set_index(["country","sector"])

# %%
all_infra
# Out:
#                                                infra_k
# country                        sector
# American Samoa                 transport           NaN
# Anguilla                       transport           NaN
# Antigua and Barbuda            transport  4.662181e+08
# Aruba                          transport           NaN
# Bahamas, The                   transport  2.480946e+09
# Bahrain                        transport           NaN
# Barbados                       transport  9.070417e+08
# Belize                         transport  2.513105e+09
# Bermuda                        transport  2.367476e+08
# Cape Verde                     transport           NaN
# Comoros                        transport           NaN
# Cook Islands                   transport           NaN
# Cuba                           transport  2.442253e+10
# Dominica                       transport  4.304822e+08
# Dominican Republic             transport  1.065118e+10
# Fiji                           transport  2.981647e+09
# Guam                           transport           NaN
# Guinea-Bissau                  transport           NaN
# Guyana                         transport           NaN
# Haiti                          transport  9.742686e+09
# Jamaica                        transport  5.119131e+09
# Kiribati                       transport  3.843400e+08
# Maldives                       transport  3.532521e+08
# Marshall Islands               transport  3.323244e+07
# Mauritius                      transport  1.900132e+09
# Micronesia, Fed. Sts.          transport  1.575350e+08
# Palau                          transport  1.026716e+08
# Papua New Guinea               transport  6.976123e+09
# Samoa                          transport  9.025303e+08
# Sao Tome and Principe          transport  3.252415e+08
# ...                                                ...
# Kiribati                       water      1.082715e+07
# Maldives                       water      2.051725e+08
# Marshall Islands               water      7.076137e+06
# Mauritius                      water      1.433295e+09
# Micronesia, Fed. Sts.          water      1.600597e+07
# Palau                          water               NaN
# Papua New Guinea               water      8.536102e+08
# Samoa                          water      7.177621e+07
# Sao Tome and Principe          water      6.562817e+07
# Seychelles                     water      1.355360e+08
# Solomon Islands                water      5.018003e+07
# St. Lucia                      water      1.170611e+08
# St. Vincent and the Grenadines water      1.010510e+08
# Timor-Leste                    water               NaN
# Tonga                          water      3.286655e+07
# Trinidad and Tobago            water               NaN
# Virgin Islands, British        water               NaN
# NaN                            water               NaN
# Nauru                          water      4.825551e+06
# New Caledonia                  water               NaN
# Niue                           water               NaN
# Northern Marianas              water               NaN
# Singapore                      water               NaN
# St. Kitts and Nevis            water               NaN
# Suriname                       water      6.110619e+08
# Timor Leste                    water               NaN
# Tuvalu                         water      3.013341e+06
# Vanuatu                        water      3.798986e+07
# Grenada                        water               NaN
# FJI est 2                      water               NaN
#
# [204 rows x 1 columns]

# %%
all_infra.dropna()
# Out:
#                                                infra_k
# country                        sector
# Antigua and Barbuda            transport  4.662181e+08
# Bahamas, The                   transport  2.480946e+09
# Barbados                       transport  9.070417e+08
# Belize                         transport  2.513105e+09
# Bermuda                        transport  2.367476e+08
# Cuba                           transport  2.442253e+10
# Dominica                       transport  4.304822e+08
# Dominican Republic             transport  1.065118e+10
# Fiji                           transport  2.981647e+09
# Haiti                          transport  9.742686e+09
# Jamaica                        transport  5.119131e+09
# Kiribati                       transport  3.843400e+08
# Maldives                       transport  3.532521e+08
# Marshall Islands               transport  3.323244e+07
# Mauritius                      transport  1.900132e+09
# Micronesia, Fed. Sts.          transport  1.575350e+08
# Palau                          transport  1.026716e+08
# Papua New Guinea               transport  6.976123e+09
# Samoa                          transport  9.025303e+08
# Sao Tome and Principe          transport  3.252415e+08
# Seychelles                     transport  1.680563e+08
# Solomon Islands                transport  5.905869e+08
# St. Lucia                      transport  6.512612e+08
# St. Vincent and the Grenadines transport  2.745274e+08
# Timor-Leste                    transport  1.857728e+09
# Tonga                          transport  5.739481e+08
# Trinidad and Tobago            transport  3.843765e+09
# American Samoa                 power      3.269578e+07
# Anguilla                       power      1.252212e+07
# Antigua and Barbuda            power      4.313640e+07
# ...                                                ...
# Niue                           building   1.368667e+08
# Tuvalu                         building   7.643333e+07
# Vanuatu                        building   9.528000e+08
# Grenada                        building   2.131954e+09
# Belize                         water      4.352581e+08
# Comoros                        water      2.001271e+08
# Cook Islands                   water      1.364416e+07
# Dominica                       water      1.020678e+08
# Fiji                           water      4.135154e+08
# Guinea-Bissau                  water      1.937911e+08
# Guyana                         water      2.428026e+08
# Haiti                          water      1.271568e+09
# Jamaica                        water      4.261407e+09
# Kiribati                       water      1.082715e+07
# Maldives                       water      2.051725e+08
# Marshall Islands               water      7.076137e+06
# Mauritius                      water      1.433295e+09
# Micronesia, Fed. Sts.          water      1.600597e+07
# Papua New Guinea               water      8.536102e+08
# Samoa                          water      7.177621e+07
# Sao Tome and Principe          water      6.562817e+07
# Seychelles                     water      1.355360e+08
# Solomon Islands                water      5.018003e+07
# St. Lucia                      water      1.170611e+08
# St. Vincent and the Grenadines water      1.010510e+08
# Tonga                          water      3.286655e+07
# Nauru                          water      4.825551e+06
# Suriname                       water      6.110619e+08
# Tuvalu                         water      3.013341e+06
# Vanuatu                        water      3.798986e+07
#
# [119 rows x 1 columns]

# %%
all_infra.sum(level="country")
# Out:
#                                      infra_k
# country
# American Samoa                  3.269578e+07
# Anguilla                        1.252212e+07
# Antigua and Barbuda             5.093545e+08
# Aruba                           9.078911e+07
# Bahamas, The                    2.848736e+09
# Bahrain                         1.121848e+10
# Barbados                        1.036892e+09
# Belize                          7.815936e+09
# Bermuda                         3.071372e+08
# Cape Verde                      1.129964e+08
# Comoros                         2.049483e+08
# Cook Islands                    4.539535e+08
# Cuba                            2.442253e+10
# Dominica                        5.565529e+08
# Dominican Republic              1.674473e+11
# FJI est 2                                NaN
# Fiji                            1.038296e+10
# Grenada                         2.131954e+09
# Guam                            2.402088e+08
# Guinea-Bissau                   2.084620e+08
# Guyana                          3.983239e+08
# Haiti                           3.780226e+10
# Jamaica                         4.838888e+10
# Kiribati                        7.355168e+08
# Maldives                        5.996905e+08
# Marshall Islands                5.236272e+08
# Mauritius                       4.070540e+09
# Micronesia, Fed. Sts.           7.702267e+08
# Nauru                           6.657895e+07
# New Caledonia                   8.887735e+08
# Niue                            1.377514e+08
# Northern Marianas               3.658471e+07
# Palau                           5.712919e+08
# Papua New Guinea                2.188859e+10
# Samoa                           1.737938e+09
# Sao Tome and Principe           4.174660e+08
# Seychelles                      3.610764e+08
# Singapore                                NaN
# Solomon Islands                 1.687884e+09
# St. Kitts and Nevis             3.219731e+07
# St. Lucia                       3.997170e+09
# St. Vincent and the Grenadines  4.076988e+08
# Suriname                        9.144616e+08
# Timor Leste                     1.362663e+08
# Timor-Leste                     7.818161e+09
# Tonga                           1.464171e+09
# Trinidad and Tobago             6.292483e+09
# Tuvalu                          8.417062e+07
# Vanuatu                         9.907899e+08
# Virgin Islands, British         2.624483e+07

# %% [markdown]
# shares = all_infra.dropna()
# shares = shares.multiply(1/shares.total,axis="index").drop("total",axis=1)

# %% [markdown]
# shares.rename(columns={'total_roads_value':"roads", 'total_power_value':"power plants", 'total_building_value':"buildings", 'total_water_value':"water"}).plot(kind="bar",stacked=True)
# plt.legend(bbox_to_anchor=(1.05, 1.0))
# plt.ylabel("Share in total infrastructure stock")
# plt.savefig("infra_share.png",bbox_inches='tight')

# %% [markdown]
# ## Read total capital data gathered in "gather_capital_data" and wb data gathered in "download_wb_data"

# %%
K = pd.read_csv("intermediate/avg_prod_k_with_gar_for_sids.csv",index_col="Unnamed: 0")
wb = pd.read_csv("inputs/wb_data.csv",index_col="country")

# %% [markdown]
# ## recomputes Ktot from WB GDP and average capital productivity

# %%
wb["Ktot"] = wb.gdp_pc_pp*wb['pop']/K.avg_prod_k
wb["GDP"] = wb.gdp_pc_pp*wb['pop']

# %%
all_infra[['Ktot','GDP']] = broadcast_simple(wb[['Ktot','GDP']],all_infra.index)
all_infra
# Out:
#                                                infra_k          Ktot  \
# country                        sector
# American Samoa                 transport           NaN           NaN
# Anguilla                       transport           NaN           NaN
# Antigua and Barbuda            transport  4.662181e+08  1.067134e+10
# Aruba                          transport           NaN  1.299863e+10
# Bahamas, The                   transport  2.480946e+09  4.717733e+10
# Bahrain                        transport           NaN  2.002349e+11
# Barbados                       transport  9.070417e+08  1.476045e+10
# Belize                         transport  2.513105e+09  1.073572e+10
# Bermuda                        transport  2.367476e+08  1.778156e+10
# Cape Verde                     transport           NaN           NaN
# Comoros                        transport           NaN  2.435707e+09
# Cook Islands                   transport           NaN           NaN
# Cuba                           transport  2.442253e+10           NaN
# Dominica                       transport  4.304822e+08  3.005842e+09
# Dominican Republic             transport  1.065118e+10  5.007692e+11
# Fiji                           transport  2.981647e+09  2.288247e+10
# Guam                           transport           NaN           NaN
# Guinea-Bissau                  transport           NaN  6.291044e+09
# Guyana                         transport           NaN  1.471736e+10
# Haiti                          transport  9.742686e+09  1.345242e+11
# Jamaica                        transport  5.119131e+09  1.161836e+11
# Kiribati                       transport  3.843400e+08  7.645732e+08
# Maldives                       transport  3.532521e+08  1.653187e+10
# Marshall Islands               transport  3.323244e+07           NaN
# Mauritius                      transport  1.900132e+09  9.148196e+10
# Micronesia, Fed. Sts.          transport  1.575350e+08           NaN
# Palau                          transport  1.026716e+08           NaN
# Papua New Guinea               transport  6.976123e+09  6.516308e+10
# Samoa                          transport  9.025303e+08           NaN
# Sao Tome and Principe          transport  3.252415e+08  4.089021e+09
# ...                                                ...           ...
# Kiribati                       water      1.082715e+07  7.645732e+08
# Maldives                       water      2.051725e+08  1.653187e+10
# Marshall Islands               water      7.076137e+06           NaN
# Mauritius                      water      1.433295e+09  9.148196e+10
# Micronesia, Fed. Sts.          water      1.600597e+07           NaN
# Palau                          water               NaN           NaN
# Papua New Guinea               water      8.536102e+08  6.516308e+10
# Samoa                          water      7.177621e+07           NaN
# Sao Tome and Principe          water      6.562817e+07  4.089021e+09
# Seychelles                     water      1.355360e+08  1.140172e+10
# Solomon Islands                water      5.018003e+07  4.184846e+09
# St. Lucia                      water      1.170611e+08  4.808258e+09
# St. Vincent and the Grenadines water      1.010510e+08  8.849700e+09
# Timor-Leste                    water               NaN  2.116321e+10
# Tonga                          water      3.286655e+07  1.596333e+09
# Trinidad and Tobago            water               NaN  1.125391e+11
# Virgin Islands, British        water               NaN           NaN
# NaN                            water               NaN           NaN
# Nauru                          water      4.825551e+06           NaN
# New Caledonia                  water               NaN           NaN
# Niue                           water               NaN           NaN
# Northern Marianas              water               NaN           NaN
# Singapore                      water               NaN  1.726796e+12
# St. Kitts and Nevis            water               NaN  7.505926e+09
# Suriname                       water      6.110619e+08  1.346866e+10
# Timor Leste                    water               NaN           NaN
# Tuvalu                         water      3.013341e+06           NaN
# Vanuatu                        water      3.798986e+07  2.600070e+09
# Grenada                        water               NaN  7.535267e+09
# FJI est 2                      water               NaN           NaN
#
#                                                    GDP
# country                        sector
# American Samoa                 transport           NaN
# Anguilla                       transport           NaN
# Antigua and Barbuda            transport  2.097770e+09
# Aruba                          transport  3.770844e+09
# Bahamas, The                   transport  8.404339e+09
# Bahrain                        transport  6.343127e+10
# Barbados                       transport  4.442594e+09
# Belize                         transport  2.873784e+09
# Bermuda                        transport  3.310277e+09
# Cape Verde                     transport           NaN
# Comoros                        transport  1.122714e+09
# Cook Islands                   transport           NaN
# Cuba                           transport           NaN
# Dominica                       transport  7.482293e+08
# Dominican Republic             transport  1.501360e+11
# Fiji                           transport  7.965477e+09
# Guam                           transport           NaN
# Guinea-Bissau                  transport  2.662299e+09
# Guyana                         transport  5.605078e+09
# Haiti                          transport  1.794108e+10
# Jamaica                        transport  2.359830e+10
# Kiribati                       transport  2.171002e+08
# Maldives                       transport  5.108243e+09
# Marshall Islands               transport  2.003310e+08
# Mauritius                      transport  2.469918e+10
# Micronesia, Fed. Sts.          transport  3.495423e+08
# Palau                          transport  3.064441e+08
# Papua New Guinea               transport  2.118981e+10
# Samoa                          transport  1.147754e+09
# Sao Tome and Principe          transport  5.984070e+08
# ...                                                ...
# Kiribati                       water      2.171002e+08
# Maldives                       water      5.108243e+09
# Marshall Islands               water      2.003310e+08
# Mauritius                      water      2.469918e+10
# Micronesia, Fed. Sts.          water      3.495423e+08
# Palau                          water      3.064441e+08
# Papua New Guinea               water      2.118981e+10
# Samoa                          water      1.147754e+09
# Sao Tome and Principe          water      5.984070e+08
# Seychelles                     water      2.491819e+09
# Solomon Islands                water      1.242422e+09
# St. Lucia                      water      1.905312e+09
# St. Vincent and the Grenadines water      1.179601e+09
# Timor-Leste                    water      2.729047e+09
# Tonga                          water      5.712251e+08
# Trinidad and Tobago            water      4.037415e+10
# Virgin Islands, British        water               NaN
# NaN                            water               NaN
# Nauru                          water      1.689914e+08
# New Caledonia                  water               NaN
# Niue                           water               NaN
# Northern Marianas              water               NaN
# Singapore                      water      4.566759e+11
# St. Kitts and Nevis            water      1.356178e+09
# Suriname                       water      7.322358e+09
# Timor Leste                    water               NaN
# Tuvalu                         water      3.756816e+07
# Vanuatu                        water      7.723966e+08
# Grenada                        water      1.385569e+09
# FJI est 2                      water               NaN
#
# [204 rows x 3 columns]

# %%
all_infra["share"] = all_infra.infra_k/all_infra.Ktot

# %% [markdown]
# sids_infra["share_transport_in_K"] = sids_infra.total_roads_value/sids_infra.Ktot
# sids_infra["share_transport_infra_but_buildings"] = sids_infra.total_roads_value/(sids_infra.total_power_value+sids_infra.total_roads_value+sids_infra.total_water_value)

# %% [markdown]
# sids_infra.dropna(subset=["share_transport_in_K"]).to_csv("for_sids_report.csv")

# %%
all_infra.share.dropna().sum(level="country")
# Out:
# country
# Antigua and Barbuda               0.047731
# Aruba                             0.006985
# Bahamas, The                      0.060384
# Bahrain                           0.056027
# Barbados                          0.070248
# Belize                            0.728031
# Bermuda                           0.017273
# Comoros                           0.084143
# Dominica                          0.185157
# Dominican Republic                0.334380
# Fiji                              0.453752
# Grenada                           0.282930
# Guinea-Bissau                     0.033136
# Guyana                            0.027065
# Haiti                             0.281007
# Jamaica                           0.416486
# Kiribati                          0.961997
# Maldives                          0.036275
# Mauritius                         0.044496
# Papua New Guinea                  0.335905
# Sao Tome and Principe             0.102094
# Seychelles                        0.031669
# Solomon Islands                   0.403332
# St. Kitts and Nevis               0.004290
# St. Lucia                         0.831314
# St. Vincent and the Grenadines    0.046069
# Suriname                          0.067896
# Timor-Leste                       0.369422
# Tonga                             0.917209
# Trinidad and Tobago               0.055914
# Vanuatu                           0.381063
# Name: share, dtype: float64

# %%
sids_infra.columns
# Out:
# Index(['total_roads_value', 'total_power_value', 'total_building_value',
#        'total_water_value', 'total', 'Ktot', 'GDP', 'transport_share',
#        'energy_share', 'building_share', 'water_share', 'other_infra_share',
#        'building_residential_share'],
#       dtype='object')

# %%
sids_infra[['transport_share', 'energy_share','building_share', 'water_share', 'building_residential_share', 'other_infra_share']].dropna().to_csv("inputs/sids_infra_stocks.csv")

# %%
sids_infra.dropna()
# Out:
#                   total_roads_value  total_power_value  total_building_value  \
# Belize                 2.513105e+09        246783703.0          4.620789e+09
# Fiji                   2.981647e+09        483010130.0          6.504790e+09
# Haiti                  9.742686e+09        223696330.0          2.656431e+10
# Jamaica                5.119131e+09        787424726.0          3.822092e+10
# Kiribati               3.843400e+08          4982963.0          3.353667e+08
# Papua New Guinea       6.976123e+09        889191070.0          1.316967e+10
# Solomon Islands        5.905869e+08         27550125.0          1.019567e+09
# St. Lucia              6.512612e+08         31402222.0          3.197446e+09
# Tonga                  5.739481e+08         15622726.0          8.417333e+08
#
#                   total_water_value         total          Ktot           GDP  \
# Belize                 4.352581e+08  7.815936e+09  1.073572e+10  2.873784e+09
# Fiji                   4.135154e+08  1.038296e+10  2.288247e+10  7.965477e+09
# Haiti                  1.271568e+09  3.780226e+10  1.345242e+11  1.794108e+10
# Jamaica                4.261407e+09  4.838888e+10  1.161836e+11  2.359830e+10
# Kiribati               1.082715e+07  7.355168e+08  7.645732e+08  2.171002e+08
# Papua New Guinea       8.536102e+08  2.188859e+10  6.516308e+10  2.118981e+10
# Solomon Islands        5.018003e+07  1.687884e+09  4.184846e+09  1.242422e+09
# St. Lucia              1.170611e+08  3.997170e+09  4.808258e+09  1.905312e+09
# Tonga                  3.286655e+07  1.464171e+09  1.596333e+09  5.712251e+08
#
#                   transport_share  energy_share  building_share  water_share  \
# Belize                   0.234088      0.022987        0.430413     0.040543
# Fiji                     0.130303      0.021108        0.284270     0.018071
# Haiti                    0.072423      0.001663        0.197469     0.009452
# Jamaica                  0.044061      0.006777        0.328970     0.036678
# Kiribati                 0.502686      0.006517        0.438633     0.014161
# Papua New Guinea         0.107056      0.013646        0.202103     0.013100
# Solomon Islands          0.141125      0.006583        0.243633     0.011991
# St. Lucia                0.135446      0.006531        0.664990     0.024346
# Tonga                    0.359542      0.009787        0.527292     0.020589
#
#                   other_infra_share  building_residential_share
# Belize                     0.493943                    0.500000
# Fiji                       0.323449                    0.629309
# Haiti                      0.208584                    0.500000
# Jamaica                    0.372426                    0.500000
# Kiribati                   0.459311                    0.500000
# Papua New Guinea           0.228848                    0.500000
# Solomon Islands            0.262207                    0.500000
# St. Lucia                  0.695867                    0.500000
# Tonga                      0.557667                    0.500000
