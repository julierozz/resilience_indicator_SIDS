# %%
# %reset-f
# %load_ext autoreload
# %autoreload 2

# %%
from res_ind_lib import *

from sorted_nicely import *
from replace_with_warning import *

import os, time
import warnings
warnings.filterwarnings("always",category=UserWarning)
from wb_api_wraper import *

# %%
import numpy as np
import pandas as pd

#Pandas display options
# pd.set_option('display.max_colwidth', 200)
# pd.set_option('display.width', 200)
# pd.set_option('display.precision', 10)
# pd.set_option('display.max_rows', 500)

#import matplotlib.pylab as plt
import matplotlib.pyplot as plt
# %matplotlib inline
font = {'family' : 'serif',
    'weight' : 'normal',
    'size'   : 15}
plt.rc('font', **font)

from fancy_plots import *

# %%
#Names to WB names
any_to_wb = pd.read_csv("inputs/any_name_to_wb_name.csv",index_col="any",squeeze=True)

#GAR names with SIDS spec
gar_name_sids = pd.read_csv("inputs/gar_name_sids.csv")

#iso3 to wb country name table
iso3_to_wb=pd.read_csv("inputs/iso3_to_wb_name.csv").set_index("iso3").squeeze()

#iso2 to iso3 table
iso2_iso3 = pd.read_csv("inputs/names_to_iso.csv", usecols=["iso2","iso3"]).drop_duplicates().set_index("iso2").squeeze() #the tables has more lines than countries to account for several ways of writing country names

# %%
gar_name_sids['wbcountry'] = gar_name_sids.reset_index().country.replace(any_to_wb)

list_of_sids = gar_name_sids[gar_name_sids.isaSID=="SIDS"].dropna().reset_index().wbcountry

# %%
penn = pd.read_excel("inputs/pwt90.xlsx","Data")

# %%
penn.columns
# Out:
# Index(['countrycode', 'country', 'currency_unit', 'year', 'rgdpe', 'rgdpo',
#        'pop', 'emp', 'avh', 'hc', 'ccon', 'cda', 'cgdpe', 'cgdpo', 'ck',
#        'ctfp', 'cwtfp', 'rgdpna', 'rconna', 'rdana', 'rkna', 'rtfpna',
#        'rwtfpna', 'labsh', 'delta', 'xr', 'pl_con', 'pl_da', 'pl_gdpo',
#        'i_cig', 'i_xm', 'i_xr', 'i_outlier', 'cor_exp', 'statcap', 'csh_c',
#        'csh_i', 'csh_g', 'csh_x', 'csh_m', 'csh_r', 'pl_c', 'pl_i', 'pl_g',
#        'pl_x', 'pl_m', 'pl_k'],
#       dtype='object')

# %%
def mrv_gp_2(x):
    """this function gets the most recent value from a dataframe grouped by country"""
    out= x.ix[(x["year"])==np.max(x["year"]),:]
    return out

# %%
hop=penn.groupby("country").apply(mrv_gp_2)
hop = hop.drop("country",axis=1).reset_index().drop("level_1",axis=1)

# %%
clean_penn = hop[['countrycode', 'country', 'currency_unit', 'year', 'rgdpe', 'rgdpo','cgdpe', 'cgdpo', 'ck']]

# %%
clean_penn.head()
# Out:
#   countrycode              country          currency_unit  year  \
# 0         ALB              Albania                    Lek  2014
# 1         DZA              Algeria         Algerian Dinar  2014
# 2         AGO               Angola                 Kwanza  2014
# 3         AIA             Anguilla  East Caribbean Dollar  2014
# 4         ATG  Antigua and Barbuda  East Caribbean Dollar  2014
#
#            rgdpe          rgdpo          cgdpe          cgdpo            ck
# 0   30816.716797   31845.375000   30575.990234   31419.962891  1.127928e+05
# 1  498826.781250  509312.531250  492537.062500  497452.875000  1.721824e+06
# 2  193041.453125  213269.265625  190432.046875  205371.265625  7.960541e+05
# 3     394.619324     296.433105     390.829956     294.655243  3.296041e+03
# 4    1909.045776    1364.635986    1892.289673    1363.846924  1.177330e+04

# %%
clean_penn["country"] = clean_penn.country.replace(any_to_wb)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
K_sids = clean_penn.set_index("country").loc[list_of_sids,:]

# %%
K_sids
# Out:
#                                countrycode               currency_unit  \
# country
# American Samoa                         NaN                         NaN
# Anguilla                               AIA       East Caribbean Dollar
# Antigua and Barbuda                    ATG       East Caribbean Dollar
# Aruba                                  ABW              Aruban Guilder
# Bahamas, The                           BHS             Bahamian Dollar
# Bahrain                                BHR              Bahraini Dinar
# Barbados                               BRB             Barbados Dollar
# Belize                                 BLZ               Belize Dollar
# Bermuda                                BMU            Bermudian Dollar
# Virgin Islands, British                VGB                   US Dollar
# Cape Verde                             CPV           Cabo Verde Escudo
# Cayman Islands                         CYM       Cayman Islands Dollar
# Comoros                                COM                Comoro Franc
# Cuba                                   NaN                         NaN
# Dominica                               DMA       East Caribbean Dollar
# Dominican Republic                     DOM              Dominican Peso
# Fiji                                   FJI                 Fiji Dollar
# French Polynesia                       NaN                         NaN
# Grenada                                GRD       East Caribbean Dollar
# Guinea-Bissau                          GNB             CFA Franc BCEAO
# Guyana                                 NaN                         NaN
# Haiti                                  HTI                      Gourde
# Jamaica                                JAM             Jamaican Dollar
# Kiribati                               NaN                         NaN
# Maldives                               MDV                     Rufiyaa
# Marshall Islands                       NaN                         NaN
# Mauritius                              MUS             Mauritius Rupee
# Micronesia, Fed. Sts.                  NaN                         NaN
# New Caledonia                          NaN                         NaN
# Palau                                  NaN                         NaN
# Papua New Guinea                       NaN                         NaN
# Puerto Rico                            NaN                         NaN
# St. Kitts and Nevis                    KNA       East Caribbean Dollar
# St. Lucia                              LCA       East Caribbean Dollar
# St. Vincent and the Grenadines         VCT       East Caribbean Dollar
# Sao Tome and Principe                  STP                       Dobra
# Seychelles                             SYC            Seychelles Rupee
# Singapore                              SGP            Singapore Dollar
# Solomon Islands                        NaN                         NaN
# Suriname                               SUR              Surinam Dollar
# Timor-Leste                            NaN                         NaN
# Tonga                                  NaN                         NaN
# Trinidad and Tobago                    TTO  Trinidad and Tobago Dollar
# Turks and Caicos Islands               TCA                   US Dollar
# Tuvalu                                 NaN                         NaN
# Virgin Islands (U.S.)                  NaN                         NaN
# Vanuatu                                NaN                         NaN
#
#                                   year          rgdpe          rgdpo  \
# country
# American Samoa                     NaN            NaN            NaN
# Anguilla                        2014.0     394.619324     296.433105
# Antigua and Barbuda             2014.0    1909.045776    1364.635986
# Aruba                           2014.0    3924.260254    3858.201416
# Bahamas, The                    2014.0    8983.257812    8118.815918
# Bahrain                         2014.0   56691.871094   53291.050781
# Barbados                        2014.0    4029.591553    2901.101807
# Belize                          2014.0    2951.942627    2783.329102
# Bermuda                         2014.0    3588.543701    2331.326172
# Virgin Islands, British         2014.0     798.074585     753.338501
# Cape Verde                      2014.0    3232.399902    3351.530518
# Cayman Islands                  2014.0    3045.288086     272.078125
# Comoros                         2014.0    1124.220215    1178.298706
# Cuba                               NaN            NaN            NaN
# Dominica                        2014.0     737.030701     664.785828
# Dominican Republic              2014.0  130188.648438  132476.828125
# Fiji                            2014.0    7010.678223    6359.188477
# French Polynesia                   NaN            NaN            NaN
# Grenada                         2014.0    1186.353638    1130.820312
# Guinea-Bissau                   2014.0    2252.452148    2272.609863
# Guyana                             NaN            NaN            NaN
# Haiti                           2014.0   16517.289062   17735.093750
# Jamaica                         2014.0   20734.019531   20293.226562
# Kiribati                           NaN            NaN            NaN
# Maldives                        2014.0    5143.455566    6125.611816
# Marshall Islands                   NaN            NaN            NaN
# Mauritius                       2014.0   22760.681641   23067.927734
# Micronesia, Fed. Sts.              NaN            NaN            NaN
# New Caledonia                      NaN            NaN            NaN
# Palau                              NaN            NaN            NaN
# Papua New Guinea                   NaN            NaN            NaN
# Puerto Rico                        NaN            NaN            NaN
# St. Kitts and Nevis             2014.0    1281.525879    1144.848633
# St. Lucia                       2014.0    1848.785522    1937.394165
# St. Vincent and the Grenadines  2014.0    1051.593384     944.865967
# Sao Tome and Principe           2014.0     603.615051     648.693054
# Seychelles                      2014.0    2475.496338    2386.640625
# Singapore                       2014.0  399684.500000  366089.406250
# Solomon Islands                    NaN            NaN            NaN
# Suriname                        2014.0    8426.287109    7917.651367
# Timor-Leste                        NaN            NaN            NaN
# Tonga                              NaN            NaN            NaN
# Trinidad and Tobago             2014.0   42254.324219   42816.246094
# Turks and Caicos Islands        2014.0     703.580688      80.530022
# Tuvalu                             NaN            NaN            NaN
# Virgin Islands (U.S.)              NaN            NaN            NaN
# Vanuatu                            NaN            NaN            NaN
#
#                                         cgdpe          cgdpo            ck
# country
# American Samoa                            NaN            NaN           NaN
# Anguilla                           390.829956     294.655243  3.296041e+03
# Antigua and Barbuda               1892.289673    1363.846924  1.177330e+04
# Aruba                             3875.619629    3716.979248  3.233623e+04
# Bahamas, The                      8873.968750    8009.972656  4.292221e+04
# Bahrain                          56282.136719   52476.320312  2.262300e+05
# Barbados                          4003.140381    2830.756348  1.583953e+04
# Belize                            2946.158936    2736.465820  5.175436e+03
# Bermuda                           3567.483154    2286.531494  1.228239e+04
# Virgin Islands, British            791.822998     786.239746  2.699884e+03
# Cape Verde                        3192.275146    3289.493408  1.498158e+04
# Cayman Islands                    3015.826416     266.871155  1.429500e+04
# Comoros                           1124.567993    1170.055054  2.337471e+03
# Cuba                                      NaN            NaN           NaN
# Dominica                           733.080139     655.754761  2.189096e+03
# Dominican Republic              129506.343750  131433.609375  4.331949e+05
# Fiji                              6965.324707    6304.348145  1.619764e+04
# French Polynesia                          NaN            NaN           NaN
# Grenada                           1180.880737    1121.628174  5.848608e+03
# Guinea-Bissau                     2254.273438    2262.511475  5.404101e+03
# Guyana                                    NaN            NaN           NaN
# Haiti                            16377.560547   17441.189453  1.307759e+05
# Jamaica                          20602.666016   20034.494141  1.356549e+05
# Kiribati                                  NaN            NaN           NaN
# Maldives                          5091.157227    6041.848145  1.360284e+04
# Marshall Islands                          NaN            NaN           NaN
# Mauritius                        22551.175781   22719.138672  8.445367e+04
# Micronesia, Fed. Sts.                     NaN            NaN           NaN
# New Caledonia                             NaN            NaN           NaN
# Palau                                     NaN            NaN           NaN
# Papua New Guinea                          NaN            NaN           NaN
# Puerto Rico                               NaN            NaN           NaN
# St. Kitts and Nevis               1270.288574    1140.040649  7.831756e+03
# St. Lucia                         1834.531616    1898.569702  7.987611e+03
# St. Vincent and the Grenadines    1043.552856     934.773010  7.012931e+03
# Sao Tome and Principe              593.500671     634.810059  4.084982e+03
# Seychelles                        2443.964355    2345.403320  1.073177e+04
# Singapore                       394093.218750  363712.187500  1.607120e+06
# Solomon Islands                           NaN            NaN           NaN
# Suriname                          8300.525391    7784.789551  3.882485e+04
# Timor-Leste                               NaN            NaN           NaN
# Tonga                                     NaN            NaN           NaN
# Trinidad and Tobago              42059.699219   41967.992188  1.953341e+05
# Turks and Caicos Islands           699.736755      76.524857  2.112082e+03
# Tuvalu                                    NaN            NaN           NaN
# Virgin Islands (U.S.)                     NaN            NaN           NaN
# Vanuatu                                   NaN            NaN           NaN
